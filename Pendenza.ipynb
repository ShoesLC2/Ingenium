# %% [markdown]
# script python che ci permette di determinare la pendenza della curva di una funzione in qualsiasi punto

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
    return(x**3+x**2-5*x+2)

# %%
f(0)
# Out:
# 2

# %%
x=np.linspace(-10,10,104)
print(x)
# Out:
# [-10.          -9.80582524  -9.61165049  -9.41747573  -9.22330097
#   -9.02912621  -8.83495146  -8.6407767   -8.44660194  -8.25242718
#   -8.05825243  -7.86407767  -7.66990291  -7.47572816  -7.2815534
#   -7.08737864  -6.89320388  -6.69902913  -6.50485437  -6.31067961
#   -6.11650485  -5.9223301   -5.72815534  -5.53398058  -5.33980583
#   -5.14563107  -4.95145631  -4.75728155  -4.5631068   -4.36893204
#   -4.17475728  -3.98058252  -3.78640777  -3.59223301  -3.39805825
#   -3.2038835   -3.00970874  -2.81553398  -2.62135922  -2.42718447
#   -2.23300971  -2.03883495  -1.84466019  -1.65048544  -1.45631068
#   -1.26213592  -1.06796117  -0.87378641  -0.67961165  -0.48543689
#   -0.29126214  -0.09708738   0.09708738   0.29126214   0.48543689
#    0.67961165   0.87378641   1.06796117   1.26213592   1.45631068
#    1.65048544   1.84466019   2.03883495   2.23300971   2.42718447
#    2.62135922   2.81553398   3.00970874   3.2038835    3.39805825
# ...

# %%
y=f(x)
print(y)
# Out:
# [-8.48000000e+02 -7.95688032e+02 -7.45518959e+02 -6.97448856e+02
#  -6.51433795e+02 -6.07429848e+02 -5.65393091e+02 -5.25279595e+02
#  -4.87045434e+02 -4.50646681e+02 -4.16039410e+02 -3.83179693e+02
#  -3.52023603e+02 -3.22527215e+02 -2.94646601e+02 -2.68337834e+02
#  -2.43556987e+02 -2.20260135e+02 -1.98403349e+02 -1.77942703e+02
#  -1.58834271e+02 -1.41034125e+02 -1.24498339e+02 -1.09182985e+02
#  -9.50441382e+01 -8.20378704e+01 -7.01202551e+01 -5.92473655e+01
#  -4.93752749e+01 -4.04600564e+01 -3.24577831e+01 -2.53245285e+01
#  -1.90163655e+01 -1.34893674e+01 -8.69960750e+00 -4.60315889e+00
#  -1.15609480e+00  1.68551157e+00  3.96558701e+00  5.72805833e+00
#   7.01685233e+00  7.87589581e+00  8.34911556e+00  8.48043839e+00
#   8.31379109e+00  7.89310047e+00  7.26229333e+00  6.46529646e+00
#   5.54603666e+00  4.54844074e+00  3.51643549e+00  2.49394771e+00
#   1.52490421e+00  6.53231777e-01 -7.71427813e-02 -6.22292668e-01
# ...

# %%
plt.figure(figsize=(8, 5))
plt.figure(figsize=(8, 5))
plt.plot(x, y)  # rimosso marker='o'
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Grafico di y = f(x) per x in [-10, 10] e y in [-10, 10]')
plt.grid(True)
plt.show()

# %%
def m(x):
    dx=le-5
    return (f(x+dx)-f(x))/(dx)

# %%
# Calcolo la derivata numerica m(x) usando il metodo delle differenze finite
dx = 1e-5
m_values = (f(x + dx) - f(x)) / dx

plt.figure(figsize=(8, 5))
plt.plot(x, y, label='f(x)')
plt.plot(x, m_values, label="m(x) - derivata numerica", linestyle='--')
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.xlabel('x')
plt.ylabel('y / m(x)')
plt.title('f(x) e m(x) sullo stesso diagramma')
plt.grid(True)
plt.legend()
plt.show()
